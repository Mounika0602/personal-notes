# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
#IMPORTED ALL REQUIRED LIBRARIES
#IMPORTED DATA FROM CSV FILE INTO PYTHON
data=pd.read_csv("micro credit file.csv")
data
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
#JUST TO CHECK ONLY 5 ROWS AND COLUMNS 
data.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
#DROPPED FOUR VARIBALES AS THEY ARE NOT ADDING MUCH VALUE TO DATA
data1=data.drop(['pcircle','pdate','msisdn','Unnamed: 0'],axis=1)
data1
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
# CHECKED THE SHAPE OF THE NEW DATA AFTER DDROPPING
data1.shape
# Out:
# (209593, 33)

# %%
#CHECKED THE DATA TYPES OF ALL THE VARIBALES PRESENT IN DATASET
data1.dtypes
# Out:
# label                     int64
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# cnt_loans90             float64
# amnt_loans90              int64
# ...

# %%
#CHECKED ALL THE COLUMNS PRESENT IN DATASET
data1.columns
# Out:
# Index(['label', 'aon', 'daily_decr30', 'daily_decr90', 'rental30', 'rental90',
#        'last_rech_date_ma', 'last_rech_date_da', 'last_rech_amt_ma',
#        'cnt_ma_rech30', 'fr_ma_rech30', 'sumamnt_ma_rech30',
#        'medianamnt_ma_rech30', 'medianmarechprebal30', 'cnt_ma_rech90',
#        'fr_ma_rech90', 'sumamnt_ma_rech90', 'medianamnt_ma_rech90',
#        'medianmarechprebal90', 'cnt_da_rech30', 'fr_da_rech30',
#        'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30', 'amnt_loans30',
#        'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90', 'amnt_loans90',
#        'maxamnt_loans90', 'medianamnt_loans90', 'payback30', 'payback90'],
#       dtype='object')

# %%
#CHECKED THE COMPLETE INFORMATION OF DATASET
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 33 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   aon                   209593 non-null  float64
#  2   daily_decr30          209593 non-null  float64
#  3   daily_decr90          209593 non-null  float64
#  4   rental30              209593 non-null  float64
#  5   rental90              209593 non-null  float64
#  6   last_rech_date_ma     209593 non-null  float64
#  7   last_rech_date_da     209593 non-null  float64
#  8   last_rech_amt_ma      209593 non-null  int64
#  9   cnt_ma_rech30         209593 non-null  int64
#  10  fr_ma_rech30          209593 non-null  float64
#  11  sumamnt_ma_rech30     209593 non-null  float64
#  12  medianamnt_ma_rech30  209593 non-null  float64
#  13  medianmarechprebal30  209593 non-null  float64
# ...

# %%
# SUMMARY STATISTICS
#FOUND NO MISSING VALUES IN THE DATASET
data1.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
# HERE WE CAN SEE THAT THE MEAN IS LESS THAN COMPARED TO 3 QURTILES
# IN 25TH 50TH 75TH QUARTILE THE VALUE IS SAME

# %%
# CHECKING IF THERE ARE ANY MISSING VALUES OR NOT
data1.isnull().sum()
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# dtype: int64

# %%
#LETS CHECK MISSING VALUES WITH THE HELP OF HEATMAP
# FOUND NO MISSING VALUES
sns.heatmap(data1.isnull())
# Out:
# <AxesSubplot:>

# %%
data1['label'].plot(kind="hist")
plt.title("The Relation Between Variable and Target")
plt.ylabel("lable  target")
plt.xlabel("maxamnt_loans90  variable")
plt.show()

# FOUND THAT WHEN LOANS ARE INCREASING THE TRAGET IS ALSO INCRESING

# %%
data1['daily_decr30'].plot(kind="hist")
plt.title("The Relation Between Variable and Target")
plt.ylabel("lable  target")
plt.xlabel("daily_decr30  variable")
plt.show()

# HERE WHEN LOANS ARE DECRESING THE TARGET IS ALSO DECREASING

# %%
plt.figure()
pd.Series(data1['label']).value_counts().sort_index().plot(kind = 'bar')
plt.ylabel("label")
plt.xlabel("variable")
plt.title('Number of defaulters and non defaulters (0=defaulter, 1=non defaulter)')

# CHECKING HOW MANY ARE DAFAULTERS AND NON DEFAULTERS USING HISTOGRAM
# FOUND THAT NON DEFAULTERS ARE MORE COMPARED TO DEFAULTERS
# Out:
# Text(0.5, 1.0, 'Number of defaulters and non defaulters (0=defaulter, 1=non defaulter)')

# %%
#NOEW LETS CHECK CORRELATION WITH THE HELP OF HEATMAP
data1cor=data1.corr()
data1
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
sns.heatmap(data1cor)

# THE WHITE AREA IS HIGHLY CORRELATED
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(4,6))
sns.heatmap(data1cor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
# LETS CHECK THE OUTLIERS AND REMOVE THEM WITH THE HELP OF BOX PLOT
from scipy.stats import zscore
z=np.abs(zscore(data1))
z
# Out:
# array([[2.64789583, 0.10357685, 0.25229941, ..., 0.22959366, 2.9046997 ,
#         2.39409346],
#        [0.37765836, 0.09776412, 0.73103667, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        [0.37765836, 0.10010243, 0.43201111, ..., 0.22959366, 0.38562959,
#         0.41923266],
#        ...,
#        [0.37765836, 0.09378769, 0.70079045, ..., 0.22959366, 0.06820893,
#         0.04735622],
#        [0.37765836, 0.08428915, 0.77075515, ..., 0.22959366, 0.38562959,
#         0.59938541],
#        [0.37765836, 0.08628398, 0.09674426, ..., 0.22959366, 0.38562959,
#         0.41923266]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([15, 15, 32, ..., 28, 26, 30], dtype=int64))

# %%
data1['daily_decr90'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data1['maxamnt_loans30'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data1_new=data1[(z<3).all(axis=1)]
data1_new
#REMOVED OUTLIERS
# Out:
#         label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0           0   272.0   3055.050000   3065.150000    220.13    260.13
# 1           1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2           1   535.0   1398.000000   1398.000000    900.13    900.13
# 3           1   241.0     21.228000     21.228000    159.42    159.42
# 4           1   947.0    150.619333    150.619333   1098.90   1098.90
# ...       ...     ...           ...           ...       ...       ...
# 209588      1   404.0    151.872333    151.872333   1089.19   1089.19
# 209589      1  1075.0     36.936000     36.936000   1728.36   1728.36
# 209590      1  1013.0  11843.111667  11904.350000   5861.83   8893.20
# 209591      1  1732.0  12488.228333  12574.370000    411.83    984.58
# 209592      1  1581.0   4489.362000   4534.820000    483.92    631.20
#
#         last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# ...

# %%
data1.shape
# Out:
# (209593, 33)

# %%
data1_new.shape
# Out:
# (161465, 33)

# %%
x=data1_new.iloc[:,2:]
x
# Out:
#         daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0        3055.050000   3065.150000    220.13    260.13                2.0
# 1       12122.000000  12124.750000   3691.26   3691.26               20.0
# 2        1398.000000   1398.000000    900.13    900.13                3.0
# 3          21.228000     21.228000    159.42    159.42               41.0
# 4         150.619333    150.619333   1098.90   1098.90                4.0
# ...              ...           ...       ...       ...                ...
# 209588    151.872333    151.872333   1089.19   1089.19                1.0
# 209589     36.936000     36.936000   1728.36   1728.36                4.0
# 209590  11843.111667  11904.350000   5861.83   8893.20                3.0
# 209591  12488.228333  12574.370000    411.83    984.58                2.0
# 209592   4489.362000   4534.820000    483.92    631.20               13.0
#
#         last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# ...

# %%
y=data1_new.iloc[:,0]
y
# Out:
# 0         0
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 209588    1
# 209589    1
# 209590    1
# 209591    1
# 209592    1
# Name: label, Length: 161465, dtype: int64

# %%
#target/dependent variable is label
#rest all are idependent variables
#now lets train the model and fit the variables into the model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=20,random_state=42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (161445, 31)
# (161445,)
# (20, 31)
# (20,)

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
#WE HAVE TRAINED THIS MODEL IT IS SHOWING ACCURACY AS 95%
# Out:
# 0.95
# [[ 0  0]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.95        20
#    macro avg       0.50      0.47      0.49        20
# weighted avg       1.00      0.95      0.97        20

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
#WE HAVE TRAINED THIS MODEL IT IS SHOWING ACCURACY AS 95%
# Out:
# 0.95
# [[ 0  0]
#  [ 1 19]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.95      0.97        20
#
#     accuracy                           0.95        20
#    macro avg       0.50      0.47      0.49        20
# weighted avg       1.00      0.95      0.97        20

# %%
svc=SVC()

# %%
svc.fit(x_train,y_train)

# %% [raw]
# svc.score(x_train,y_train)

# %% [raw]
# predsvc=svc.predict(x_test)

# %% [raw]
# print(accuracy_score(y_test,predsvc))

# %% [raw]
# print(confusion_matrix(y_test,predsvc))

# %% [raw]
# print(classification_report(y_test,predsvc))
# #WE HAVE TRAINED THIS MODEL IT IS SHOWING ACCURACY AS 100%

# %% [raw]
# svc=SVC(kernel='rbf')
# svc.fit(x_train,y_train)
# svc.score(x_train,y_train)
# predsvc=svc.predict(x_test)
# print(accuracy_score(y_test,predsvc))
# print(confusion_matrix(y_test,predsvc))
# print(classification_report(y_test,predsvc))

# %% [markdown]
# ESEMBLE TECHNIQUES---- CLASSIFIER

# %%
#LETS USE ESEMBLE TECHINQUES FOR EVALUATING THE PERFORMANCE 
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=100,random_state=42)
#randomforesctclassifier(100)---default
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
#WE HAVE TRAINED THIS MODEL IT IS SHOWING ACCURACY AS 100%

# %%
from sklearn.ensemble import AdaBoostClassifier
#adaboost classifier (base_estimator=decisiontreeclassifier(),n_estimators=50,learning_rate=1.0)
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
#WE HAVE TRAINED THIS MODEL IT IS SHOWING ACCURACY AS 100%

# %%
#import support vector classifier
from sklearn.svm import SVC
svc=SVC()

#CREATE ADABOOST CLASSIFIER OBJECT
ad=AdaBoostClassifier(n_estimators=50,base_estimator=svc,algorithm='SAMME')
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))

# %%
from sklearn.svm import SVC
svc=SVC(probability=True,kernel='linear')
ad=AdaBoostClassifier(n_estimators=50,base_estimator=svc)
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
gb_pred=gb.predict(x_test)
print(accuracy_score(y_test,gb_pred))
print(confusion_matrix(y_test,gb_pred))
print(classification_report(y_test,gb_pred))

# %%
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV
iris = datasets.load_iris()
parameters = {'kernel':['linear','rbf'],'C':[1, 10]}
svc = svm.SVC()
clf = GridSearchCV(svc, parameters)
clf.fit(x,y) 
clf

# %% [markdown]
# GRID SEARCHCV

# %% [raw]
# from sklearn import datasets
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.model_selection import GridSearchCV
#
# dtc = DecisionTreeClassifier()
# grid_param = {
#     'criterion' : ['gini','entropy']
#     }
# gd_sr = GridSearchCV(estimator=dtc,
#                      param_grid=grid_param,
#                      scoring='accuracy',
#                      cv=5)
# gd_sr.fit(x,y)
#
# best_parameters = gd_sr.best_params_
# print(best_parameters)
# best_result = gd_sr.best_score_
# print(best_result)

# %% [raw]
# dtc=DecisionTreeClassifier(criterion='gini')
# dtc.fit(iris.data,iris.target)
# dtc.score(x,y)

# %% [raw]
# from sklearn.metrics import roc_curve
# import matplotlib.pyplot as plt
# from sklearn.metrics import roc_auc_score

# %% [raw]
# y_pred_prob=lg.predict_proba(test_x)[:,1]

# %% [raw]
# y_pred_prob

# %% [raw]
# fpr,tpr,thresholds=roc_curve(test_y,y_pred_prob)

# %% [raw]
# fpr

# %% [raw]
# tpr

# %% [raw]
# thresholds

# %% [raw]
# auc_score=roc_auc_score(test_y,lg.predict(test_x))

# %% [raw]
# print(auc_score)

# %% [raw]
# from sklearn.tree import DecisionTreeClassifier
# dt=DecisionTreeClassifier()
# dt.fit(train_x,train_y)
# p=dt.predict(test_x)
# print(accuracy_score(test_y,p))

# %% [raw]
# #decison tree curve
# y_pred_prob=dt.predict_proba(test_x)[:,1]
# fpr,tpr,thresholds=roc_curve(test_y,y_pred_prob)
# plt.plot([0,1],[0,1],'k--')
# plt.plot(fpr,tpr,label='Decision tree classifier')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Decision tree classifier')
# plt.show()
# auc_score=auc_score=roc_auc_score(test_y,lg.predict(test_x))
# auc_score

# %% [raw]
# from sklearn.neighbors import KNeighborsClassifier
# knn=KNeighborsClassifier()
# knn.fit(train_x,train_y)
# p=knn.predict(test_x)
# print(accuracy_score(test_y,p))

# %% [raw]
# #knn
# y_pred_prob=knn.predict_proba(test_x)[:,1]
# fpr,tpr,thresholds=roc_curve(test_y,y_pred_prob)
# plt.plot([0,1],[0,1],'k--')
# plt.plot(fpr,tpr,label='K nearest neighbor')
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('K nearest neighbor')
# plt.show()
# auc_score=auc_score=roc_auc_score(test_y,lg.predict(test_x))
# auc_score

# %% [markdown]
# CROSS VALIDATION

# %% [raw]
# from sklearn.model_selection import cross_val_score
# from sklearn.naive_bayes import MultinomialNB
# mnbscores = cross_val_score(mnb,x,y, cv=5)
# print(mnbscores)
# print(mnbscores.mean(),mnbscores.std())

# %% [raw]
# svcscores = cross_val_score(svc,x,y, cv=5)
# print(svcscores)
# print(svcscores.mean(),svcscores.std())

# %% [raw]
# dtcscores = cross_val_score(dtc,x,y, cv=5)
# print(dtcscores)
# print(dtcscores.mean(),dtcscores.std())

# %% [raw]
# knnscores = cross_val_score(knn,x,y, cv=5)
# print(knnscores)
# print(knnscores.mean(),knnscores.std())

# %% [markdown]
# SAVING THE BEST MODEL

# %% [raw]
# import joblib
# joblib.dump(dtc,'dtcfile.obj')
# dtc_from_joblib=joblib.load('dtcfile.obj')
# dtc_from_joblib.predict(x_test)
